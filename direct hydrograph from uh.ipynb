# %%
import numpy as np
import matplotlib.pyplot as plt
x=t= np.array([0,3,6,9,12,15,18,24,30,36,42,48,54,50,69])
#print(t)
rfe=3.5
#tint=3
#print(ti)
y=uho=np.array([0,25,50,85,125,160,110,60,36,25,16,6,0,0,0])
y2=dho=rfe*uho
print("dho",dho)
#fig = plt.figure()
ax = plt.subplot(111)
ax.plot(x,y,label="unit hydrograph")
ax.plot(x,y2,label="direct runoff hydrograph")
ax.legend()
#plt.show()
plt.title("Surface runoff from unit hydrograph")
plt.xlabel('Time in hrs')
plt.ylabel('Discharge in cumecs')

#plt.show()
# Out:
# dho [  0.   87.5 175.  297.5 437.5 560.  385.  210.  126.   87.5  56.   21.
#    0.    0.    0. ]
# Text(0, 0.5, 'Discharge in cumecs')
